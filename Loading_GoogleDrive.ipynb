# %% [markdown]
# <a href="https://colab.research.google.com/github/RYOTA2528/-Start-3-3/blob/main/Loading_GoogleDrive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %%
# ファイルの読み込み（）
file_path= './drive/MyDrive/pandas-dataset/dataset/dataset/countries_codes_and_coordinates.csv'
df = pd.read_csv(file_path, sep= ',' ,usecols=[0, 1]) #特定のカラムだけを読み込む

# %%
df.head(2)
# Out:
#        Country Alpha-2 code
# 0  Afghanistan         "AF"
# 1      Albania         "AL"

# %%
file_path_excel= './drive/MyDrive/pandas-dataset/dataset/dataset/sales_transactions.xlsx'
pd.read_excel(file_path_excel)
# Out:
#      Unnamed: 0        ymd       transaction_id  SKU  transaction_type  \
# 0             0 2020-01-07  250-0042069-0262213   60                 0
# 1             1 2020-01-07  250-0042069-0262213   60                 0
# 2             2 2020-01-07  250-0042069-0262213   60                 0
# 3             3 2020-01-07  250-0042069-0262213   60                 0
# 4             4 2020-01-07  250-0042069-0262213   60                 0
# ..          ...        ...                  ...  ...               ...
# 592         609 2019-11-20  503-0100465-6209437    2                 0
# 593         610 2019-11-20  503-0100465-6209437    2                 0
# 594         611 2019-11-20  503-0100465-6209437    2                 0
# 595         612 2019-11-20  503-0100465-6209437    2                 0
# 596         613 2019-11-20  503-0100465-6209437    2                 0
#
#      payment  details  revenue  quantity  product_name
# 0          1        4     -314       NaN            21
# ...

# %%
df = px.data.gapminder()
country_master_df = pd.read_csv(file_path, sep=',', usecols=[2, 4, 5])

# %%
country_master_df.head()
# Out:
#   Alpha-3 code Latitude (average) Longitude (average)
# 0        "AFG"               "33"                "65"
# 1        "ALB"               "41"                "20"
# 2        "DZA"               "28"                 "3"
# 3        "ASM"         "-14.3333"              "-170"
# 4        "AND"             "42.5"               "1.6"

# %%
country_master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 256 entries, 0 to 255
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Alpha-3 code         256 non-null    object
#  1   Latitude (average)   256 non-null    object
#  2   Longitude (average)  256 non-null    object
# dtypes: object(3)
# memory usage: 6.1+ KB

# %%
df.head()
#今回はiso_alphaをキーにマージしてみる
# ””が入ってしまってるためまずはこちらの除去から始める
for col in country_master_df.columns:
  country_master_df[col] = country_master_df[col].apply(lambda x: x.strip()[1:-1]) #strip()は空白の除去、[1:-1]で最初の１文字と最後の１文字を除去

# %%
country_master_df
# Out:
#     Alpha-3 code Latitude (average) Longitude (average)
# 0
# 1
# 2
# 3                              4.33
# 4
# ..           ...                ...                 ...
# 251                               3                  76
# 252
# 253
# 254
# 255
#
# [256 rows x 3 columns]

# %%
pd.merge(df, country_master_df.drop_duplicates(), left_on='iso_alpha', right_on='Alpha-3 code', how='inner')
# Out:
# Empty DataFrame
# Columns: [country, continent, year, lifeExp, pop, gdpPercap, iso_alpha, iso_num, Alpha-3 code, Latitude (average), Longitude (average)]
# Index: []
